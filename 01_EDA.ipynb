# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Get Data

# %%
dados = pd.read_csv('Dados\dados_reduzidos.csv')
dados_generos = pd.read_csv('Dados\data_w_genres.csv')
dados_anos = pd.read_csv('Dados\data_by_year.csv')

# %% [markdown]
# # EDA

# %%
dados.head()
# Out:
#    valence  year  acousticness  \
# 0   0.0594  1921         0.982
# 1   0.0394  1921         0.961
# 2   0.1960  1921         0.579
# 3   0.0731  1921         0.993
# 4   0.7210  1921         0.996
#
#                                              artists  danceability  \
# 0                                Sergei Rachmaninoff         0.279
# 1  KHP Kridhamardawa Karaton Ngayogyakarta Hadini...         0.328
# 2  KHP Kridhamardawa Karaton Ngayogyakarta Hadini...         0.697
# 3                                Sergei Rachmaninoff         0.389
# 4                                    Ignacio Corsini         0.485
#
#    duration_ms  energy  explicit                      id  instrumentalness  \
# 0       831667   0.211         0  4BJqT0PrAfrxzMOxytFOIz             0.878
# 1       500062   0.166         0  1o6I8BglA6ylDMrIELygv1             0.913
# 2       395076   0.346         0  4pyw9DVHGStUre4J6hPngr             0.168
# ...
